# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# C:\Users\shonk\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
df1 = pd.read_csv('nasdaq_stocks_data_1.csv')
df2 = pd.read_csv('nasdaq_stocks_data_2.csv')
df3 = pd.read_csv('moving_ma.csv')
df4 = pd.read_csv('stock_percent_changes.csv')
df5 = pd.read_csv('nasdaq_stocks_news.csv')
data = pd.concat([df1, df2, df3, df4, df5], axis=1)

# %%
#The dividend column is an important column. Filling it with -1 if its nan which will indicate if the
# Company does not give out dividends
data['Dividends'].fillna(-1, inplace=True)
data = data.drop(columns=['Stock']) 
data.to_csv('complete_data.csv', index=False)

# %%
del data['Company Name']

# %%
data.columns
# Out:
# Index(['Shares Number', 'Volume', 'Net Income', 'Dividends', 'Employee Amount',
#        'Previous Close', 'Analysts', 'Price Target', 'Earnings Date', 'Symbol',
#        'Market Cap', 'Stock Price', 'Revenue', 'MA20', 'MA50', 'MA200',
#        '20-Day Percent Change', '100-Day Percent Change', 'News1', 'News2',
#        'News3', 'News4', 'News5'],
#       dtype='object')

# %%
# Convert relevant columns to numeric
data['Shares Number'] = pd.to_numeric(data['Shares Number'].str.replace('B', ''), errors='coerce')
data['Net Income'] = pd.to_numeric(data['Net Income'].str.replace('B', ''), errors='coerce')
data['Dividends'] = pd.to_numeric(data['Dividends'].str.replace('$', ''), errors='coerce')
data['Market Cap'] = pd.to_numeric(data['Market Cap'].str.replace('B', ''), errors='coerce')
data['Stock Price'] = pd.to_numeric(data['Stock Price'], errors='coerce')
data['Revenue'] = pd.to_numeric(data['Revenue'].str.replace('B', ''), errors='coerce')
data['Previous Close'] = pd.to_numeric(data['Previous Close'], errors='coerce')
data['Price Target'] = pd.to_numeric(data['Price Target'], errors='coerce')
data['Employee Amount'] = pd.to_numeric(data['Employee Amount'].str.replace(',', ''), errors='coerce')

# Create new columns
data['P/E Ratio'] = data['Stock Price'] / (data['Net Income'] / data['Shares Number'])
data['Dividend Yield (%)'] = (data['Dividends'] / data['Stock Price']) * 100
data['Market Cap to Revenue Ratio'] = data['Market Cap'] / data['Revenue']
data['Earnings Per Share (EPS)'] = data['Net Income'] / data['Shares Number']
data['Revenue Per Employee'] = data['Revenue'] / data['Employee Amount']
data['Target Price Difference (%)'] = ((data['Price Target'] - data['Stock Price']) / data['Stock Price']) * 100

# Display the data
data
# Out:
#       Shares Number       Volume  Net Income  Dividends  Employee Amount  \
# 0             15.20   29,834,257      101.96       1.00         161000.0
# 1             24.58  310,565,961       42.60       0.04          29600.0
# 2              7.43   10,814,122       88.14       3.00         228000.0
# 3             12.31   11,634,952       87.66       0.80         182381.0
# 4             12.31   10,831,461       87.66       0.80         182502.0
# ...             ...          ...         ...        ...              ...
# 3495            NaN      338,760         NaN        NaN            131.0
# 3496            NaN      117,841         NaN        NaN            152.0
# 3497            NaN          NaN         NaN        NaN             46.0
# 3498            NaN        1,452         NaN        NaN             43.0
# 3499            NaN      154,677         NaN        NaN             19.0
#
#       Previous Close    Analysts  Price Target Earnings Date Symbol  ...  \
# 0            226.840         Buy        236.31   Aug 1, 2024   AAPL  ...
# 1            129.370  Strong Buy        136.74  Aug 28, 2024   NVDA  ...
# 2            416.790  Strong Buy        493.97  Jul 30, 2024   MSFT  ...
# 3            167.430         Buy        200.36  Jul 23, 2024   GOOG  ...
# 4            165.620         Buy        199.27  Jul 23, 2024  GOOGL  ...
# ...              ...         ...           ...           ...    ...  ...
# 3495           1.030  Strong Buy          3.00  Aug 13, 2024   GWAV  ...
# 3496           0.462        Hold           NaN  Aug 13, 2024   LEDS  ...
# 3497             NaN         NaN           NaN           NaN   WISA  ...
# 3498           1.800         NaN           NaN   Sep 3, 2024   ASNS  ...
# 3499           0.852         NaN           NaN  Aug 14, 2024   AVTX  ...
#
#                                                   News2  \
# 0     Cramer’s week ahead: iPhone 16 launch, consume...
# 1     This semiconductor ETF just had its worst week...
# 2     Bill Gates wants to work another 20 to 30 year...
# 3     YouTube group The Try Guys quickly found succe...
# 4     YouTube group The Try Guys quickly found succe...
# ...                                                 ...
# 3495                                                NaN
# 3496                                                NaN
# 3497  WiSA Technologies to acquire assets, IP from D...
# 3498  Actelis Networks Navigates Acquisition of Qual...
# 3499  Avalo Therapeutics trading halted, volatility ...
#
#                                                   News3  \
# 0     Masimo CEO shared confidential documents with ...
# 1     Cramer: There isn’t an AI bubble, just intense...
# 2     Wells Fargo’s top picks in September include t...
# 3     Cramer pushes back against a ‘new and negative...
# 4     Cramer pushes back against a ‘new and negative...
# ...                                                 ...
# 3495                                                NaN
# 3496                                                NaN
# 3497  WiSA Technologies VP of Finance Gary Williams ...
# 3498  Actelis Receives New Order for Intelligent Tra...
# 3499  Oppenheimer Sticks to Their Buy Rating for Ava...
#
#                                                   News4  \
# 0          Keep an eye on Meta, says KKM’s Jeff Kilburg
# 1     Jim Cramer deep dives into the weakness in chi...
# 2     Cramer pushes back against a ‘new and negative...
# 3     Cramer’s week ahead: iPhone 16 launch, consume...
# 4     Cramer’s week ahead: iPhone 16 launch, consume...
# ...                                                 ...
# 3495                                                NaN
# 3496                                                NaN
# 3497  WiSA Technologies, Inc. (WISA) Q2 Earnings Che...
# 3498  Actelis Networks receives new order for ITS ne...
# 3499  Avalo Therapeutics Shareholders Back Board and...
#
#                                                   News5  P/E Ratio  \
# 0     What to expect from Apple’s ‘It’s Glowtime’ event  33.816869
# 1     Cramer pushes back against a ‘new and negative...  74.645883
# 2     OpenAI gives artists access to unreleased tool...  35.134442
# 3     Top 10 people most likely to reach trillionair...  23.512016
# 4     Top 10 people most likely to reach trillionair...  23.257839
# ...                                                 ...        ...
# 3495                                                NaN        NaN
# 3496                                                NaN        NaN
# 3497                                                NaN        NaN
# 3498  Actelis Networks Unveils Investor Communicatio...        NaN
# 3499  Avalo Reports Second Quarter 2024 Financial Re...        NaN
#
#      Dividend Yield (%) Market Cap to Revenue Ratio Earnings Per Share (EPS)  \
# 0              0.440839                         NaN                 6.707895
# 1              0.030919                         NaN                 1.733116
# 2              0.719787                         NaN                11.862719
# 3              0.477812                         NaN                 7.121040
# 4              0.483033                         NaN                 7.121040
# ...                 ...                         ...                      ...
# 3495                NaN                         NaN                      NaN
# 3496                NaN                         NaN                      NaN
# 3497                NaN                         NaN                      NaN
# 3498                NaN                         NaN                      NaN
# 3499                NaN                         NaN                      NaN
#
#      Revenue Per Employee Target Price Difference (%)
# 0                0.002395                    4.174749
# 1                0.002695                    5.696839
# 2                0.001075                   18.517719
# 3                0.001800                   19.667921
# 4                0.001799                   20.317594
# ...                   ...                         ...
# 3495                  NaN                  525.000000
# 3496                  NaN                         NaN
# 3497                  NaN                         NaN
# 3498                  NaN                         NaN
# 3499                  NaN                         NaN
#
# [3500 rows x 29 columns]

# %%
numerical_data = data.select_dtypes(include='number')

# Find correlations between numerical columns
correlation_matrix = numerical_data.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                              Shares Number  Net Income  Dividends  \
# Shares Number                     1.000000    0.531078  -0.321415
# Net Income                        0.531078    1.000000  -0.083805
# Dividends                        -0.321415   -0.083805   1.000000
# Employee Amount                   0.395881    0.311312   0.068495
# Previous Close                    0.174658    0.142211   0.626485
# Price Target                      0.167201    0.145060   0.614630
# Market Cap                        0.224230    0.728605   0.220029
# Stock Price                       0.055493    0.195542   0.352513
# Revenue                           0.550942    0.686210   0.017547
# P/E Ratio                         0.424992   -0.070560  -0.044011
# Dividend Yield (%)               -0.052547   -0.171305   0.029473
# Market Cap to Revenue Ratio       0.002006    0.201228   0.169481
# Earnings Per Share (EPS)          0.060613    0.606004   0.388143
# Revenue Per Employee             -0.034617    0.071306  -0.036431
# Target Price Difference (%)      -0.015816   -0.066040   0.037595
#
#                              Employee Amount  Previous Close  Price Target  \
# Shares Number                       0.395881        0.174658      0.167201
# Net Income                          0.311312        0.142211      0.145060
# Dividends                           0.068495        0.626485      0.614630
# Employee Amount                     1.000000        0.190222      0.181081
# Previous Close                      0.190222        1.000000      0.986207
# Price Target                        0.181081        0.986207      1.000000
# Market Cap                          0.308034        0.400859      0.367683
# Stock Price                         0.172002        0.628782      0.602441
# Revenue                             0.752420        0.139715      0.146086
# P/E Ratio                          -0.049333       -0.093859     -0.101382
# Dividend Yield (%)                 -0.053508       -0.089494     -0.086568
# Market Cap to Revenue Ratio        -0.097663        0.366760      0.356716
# Earnings Per Share (EPS)            0.079640        0.850214      0.839148
# Revenue Per Employee               -0.045687       -0.044838     -0.050323
# Target Price Difference (%)        -0.021711        0.031920      0.054231
#
#                              Market Cap  Stock Price   Revenue  P/E Ratio  \
# Shares Number                  0.224230     0.055493  0.550942   0.424992
# Net Income                     0.728605     0.195542  0.686210  -0.070560
# Dividends                      0.220029     0.352513  0.017547  -0.044011
# Employee Amount                0.308034     0.172002  0.752420  -0.049333
# Previous Close                 0.400859     0.628782  0.139715  -0.093859
# Price Target                   0.367683     0.602441  0.146086  -0.101382
# Market Cap                     1.000000     0.422290  0.528066  -0.066680
# Stock Price                    0.422290     1.000000  0.157498   0.143857
# Revenue                        0.528066     0.157498  1.000000  -0.073130
# P/E Ratio                     -0.066680     0.143857 -0.073130   1.000000
# Dividend Yield (%)            -0.088754    -0.206327 -0.049941  -0.115607
# Market Cap to Revenue Ratio    0.374036     0.470871 -0.092356   0.087448
# Earnings Per Share (EPS)       0.476618     0.449154  0.288464  -0.081984
# Revenue Per Employee          -0.013877    -0.037240  0.014148  -0.026879
# Target Price Difference (%)   -0.045191    -0.181224 -0.014645  -0.195468
#
#                              Dividend Yield (%)  Market Cap to Revenue Ratio  \
# Shares Number                         -0.052547                     0.002006
# Net Income                            -0.171305                     0.201228
# Dividends                              0.029473                     0.169481
# Employee Amount                       -0.053508                    -0.097663
# Previous Close                        -0.089494                     0.366760
# Price Target                          -0.086568                     0.356716
# Market Cap                            -0.088754                     0.374036
# Stock Price                           -0.206327                     0.470871
# Revenue                               -0.049941                    -0.092356
# P/E Ratio                             -0.115607                     0.087448
# Dividend Yield (%)                     1.000000                    -0.167316
# Market Cap to Revenue Ratio           -0.167316                     1.000000
# Earnings Per Share (EPS)              -0.196376                     0.388464
# Revenue Per Employee                  -0.014020                     0.032571
# Target Price Difference (%)            0.672737                    -0.107119
#
#                              Earnings Per Share (EPS)  Revenue Per Employee  \
# Shares Number                                0.060613             -0.034617
# Net Income                                   0.606004              0.071306
# Dividends                                    0.388143             -0.036431
# Employee Amount                              0.079640             -0.045687
# Previous Close                               0.850214             -0.044838
# Price Target                                 0.839148             -0.050323
# Market Cap                                   0.476618             -0.013877
# Stock Price                                  0.449154             -0.037240
# Revenue                                      0.288464              0.014148
# P/E Ratio                                   -0.081984             -0.026879
# Dividend Yield (%)                          -0.196376             -0.014020
# Market Cap to Revenue Ratio                  0.388464              0.032571
# Earnings Per Share (EPS)                     1.000000             -0.009902
# Revenue Per Employee                        -0.009902              1.000000
# Target Price Difference (%)                  0.220385             -0.019334
#
#                              Target Price Difference (%)
# Shares Number                                  -0.015816
# Net Income                                     -0.066040
# Dividends                                       0.037595
# Employee Amount                                -0.021711
# Previous Close                                  0.031920
# Price Target                                    0.054231
# Market Cap                                     -0.045191
# Stock Price                                    -0.181224
# Revenue                                        -0.014645
# P/E Ratio                                      -0.195468
# Dividend Yield (%)                              0.672737
# Market Cap to Revenue Ratio                    -0.107119
# Earnings Per Share (EPS)                        0.220385
# Revenue Per Employee                           -0.019334
# Target Price Difference (%)                     1.000000
