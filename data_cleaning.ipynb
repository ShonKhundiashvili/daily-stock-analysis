# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\shonk\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
df1 = pd.read_csv('nasdaq_stocks_data_1.csv')
df2 = pd.read_csv('nasdaq_stocks_data_2.csv')

df = pd.concat([df1, df2], axis=1)

# %%
#The dividend column is an important column. Filling it with -1 if its nan which will indicate if the
# Company does not give out dividends
df['Dividends'].fillna(-1, inplace=True)
# Out:
#      Shares Number      Volume Net Income Dividends Employee Amount  \
# 5           10.50B  21,904,019     44.42B        -1       1,525,000
# 8            3.19B  58,057,446     12.39B        -1         140,473
# 11         429.16M   1,302,657      7.09B        -1          13,000
# 13           1.62B  49,697,991      1.35B        -1          26,000
# 14         443.40M   1,385,944      5.08B        -1          29,945
# ...            ...         ...        ...       ...             ...
# 3495        20.74M     338,760    -17.43M        -1             131
# 3496        45.97M     117,841     -4.84M        -1             152
# 3497           NaN         NaN        NaN        -1              46
# 3498        11.77M       1,452    -19.77M        -1              43
# 3499        24.84M     154,677    -12.24M        -1              19
#
#      Previous Close    Analysts Price Target Earnings Date Symbol  \
# 5            177.04  Strong Buy       218.51  Oct 24, 2024   AMZN
# 8            220.32        Hold       202.12  Oct 16, 2024   TSLA
# 11           686.73         Buy       687.67  Oct 16, 2024   NFLX
# 13           154.98  Strong Buy       195.93  Jul 30, 2024    AMD
# 14           558.30         Buy       599.31  Sep 12, 2024   ADBE
# ...             ...         ...          ...           ...    ...
# 3495          1.030  Strong Buy         3.00  Aug 13, 2024   GWAV
# 3496          0.462        Hold          NaN  Aug 13, 2024   LEDS
# 3497            NaN         NaN          NaN           NaN   WISA
# 3498          1.800         NaN          NaN   Sep 3, 2024   ASNS
# 3499          0.852         NaN          NaN  Aug 14, 2024   AVTX
#
#                               Company Name Market Cap Stock Price  Revenue
# 5                         Amazon.com, Inc.  1,858.14B      177.04  604.33B
# 8                              Tesla, Inc.    703.84B      220.32   95.32B
# 11                           Netflix, Inc.    294.72B      686.73   36.30B
# 13            Advanced Micro Devices, Inc.    250.83B      154.98   23.28B
# 14                              Adobe Inc.    247.55B      558.30   20.43B
# ...                                    ...        ...         ...      ...
# 3495  Greenwave Technology Solutions, Inc.      9.76M        0.48   33.59M
# 3496                  SemiLEDs Corporation      9.72M        1.35    5.31M
# 3497               WiSA Technologies, Inc.      9.61M        1.71    1.79M
# 3498                Actelis Networks, Inc.      9.57M        1.59    6.02M
# 3499              Avalo Therapeutics, Inc.      9.51M        9.20  807.00K
#
# [2572 rows x 14 columns]

# %%
df
# Out:
#      Shares Number       Volume Net Income Dividends Employee Amount  \
# 0           15.20B   29,834,257    101.96B     $1.00         161,000
# 1           24.58B  310,565,961     42.60B     $0.04          29,600
# 2            7.43B   10,814,122     88.14B     $3.00         228,000
# 3           12.31B   11,634,952     87.66B     $0.80         182,381
# 4           12.31B   10,831,461     87.66B     $0.80         182,502
# ...            ...          ...        ...       ...             ...
# 3495        20.74M      338,760    -17.43M        -1             131
# 3496        45.97M      117,841     -4.84M        -1             152
# 3497           NaN          NaN        NaN        -1              46
# 3498        11.77M        1,452    -19.77M        -1              43
# 3499        24.84M      154,677    -12.24M        -1              19
#
#      Previous Close    Analysts Price Target Earnings Date Symbol  \
# 0            226.84         Buy       236.31   Aug 1, 2024   AAPL
# 1            129.37  Strong Buy       136.74  Aug 28, 2024   NVDA
# 2            416.79  Strong Buy       493.97  Jul 30, 2024   MSFT
# 3            167.43         Buy       200.36  Jul 23, 2024   GOOG
# 4            165.62         Buy       199.27  Jul 23, 2024  GOOGL
# ...             ...         ...          ...           ...    ...
# 3495          1.030  Strong Buy         3.00  Aug 13, 2024   GWAV
# 3496          0.462        Hold          NaN  Aug 13, 2024   LEDS
# 3497            NaN         NaN          NaN           NaN   WISA
# 3498          1.800         NaN          NaN   Sep 3, 2024   ASNS
# 3499          0.852         NaN          NaN  Aug 14, 2024   AVTX
#
#                               Company Name Market Cap Stock Price  Revenue
# 0                               Apple Inc.  3,448.91B      226.84  385.60B
# 1                       NVIDIA Corporation  3,179.31B      129.37   79.77B
# 2                    Microsoft Corporation  3,098.02B      416.79  245.12B
# 3                            Alphabet Inc.  2,048.89B      167.43  328.28B
# 4                            Alphabet Inc.  2,038.78B      165.62  328.28B
# ...                                    ...        ...         ...      ...
# 3495  Greenwave Technology Solutions, Inc.      9.76M        0.48   33.59M
# 3496                  SemiLEDs Corporation      9.72M        1.35    5.31M
# 3497               WiSA Technologies, Inc.      9.61M        1.71    1.79M
# 3498                Actelis Networks, Inc.      9.57M        1.59    6.02M
# 3499              Avalo Therapeutics, Inc.      9.51M        9.20  807.00K
#
# [3500 rows x 14 columns]
